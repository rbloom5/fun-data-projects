# %%
import pycrunchbase
reload(pycrunchbase)
import json
import os
import requests
import time 
import sqlite3
import datetime

conn = sqlite3.connect('crunchbase.db')
cur = conn.cursor()
# cur.execute('DROP TABLE IF EXISTS companies ')
# cur.execute('DROP TABLE IF EXISTS fundraises ')
# cur.execute('DROP TABLE IF EXISTS exits ')

cur.execute('CREATE TABLE IF NOT EXISTS companies (id INTEGER PRIMARY KEY, name TEXT UNIQUE,  \
            founded_on INTEGER, rounds INTEGER, total_raised INTEGER, exit TEXT, exit_time INT, exit_price INT)')
cur.execute('CREATE TABLE IF NOT EXISTS fundraises \
            (round_id INTEGER PRIMARY KEY, company INTEGER, type TEXT, round TEXT, \
            amount REAL, time INTEGER)')
cur.execute('CREATE TABLE IF NOT EXISTS exits (company INTEGER, type TEXT, time INTEGER)')

conn.commit()
conn.close()


def get_uuid(obj):
    return obj[0].uuid



print "started"


conn = sqlite3.connect('crunchbase.db')
cur = conn.cursor()
Health_diagnostics = '8c1b0c584cc65d0a0208f656f91e4c82'
Biotechnology = '588427287ab95bd1bb67e8e55f6520a0'
cb = pycrunchbase.CrunchBase('ac51fb43c39076f46b9b3e2d04237b23')

counter = 0
other_counter = 0
company_list = []

#get a list of all the biotechnology companies


for page in range(5,7):        
    request_string = "https://api.crunchbase.com/v/2/organizations?category_uuids=3f21415b57846be63722eb189190b7cd&user_key=ac51fb43c39076f46b9b3e2d04237b23&page="+str(page) 
    company_request = requests.get(request_string)
    if page == 5:
        start=150
    else:
        start=0
    for item in company_request.json()['data']['items'][start:]:

        counter +=1
        if counter == 45:
            counter = 0
            other_counter +=1
            print other_counter
#             time.sleep(60)


        #get the organization object for each biotech company
        try:
            org = cb.organization(item['path'][13:])
        except:
            time.sleep(120)
            try:
                org = cb.organization(item['path'][13:])
            except:
                continue

                

        
        if not org.description:
            continue
        if org.funding_rounds and ('diagnostic' in org.description or 'diagnostic' in org.name):
            #if it seems like a diagnostic start-up (fundraise + diagnostic description) add to list
            company_link = item[13:]
            company_list.append(company_link)

            if org.founded_on:
                founding_date = int(org.founded_on.strftime('%Y'))
            else:
                founding_date = None

            try:
                cur.execute('INSERT INTO companies (name, founded_on, rounds, total_raised) VALUES (?,?,?,?)', \
                        (company_link, founding_date,len(org.funding_rounds), org.total_funding_usd) )

            except:
                continue

            #input acquisition data
            if org.ipo:
                current_ipo = cb.ipo(org.ipo[0].uuid)
                if current_ipo.went_public_on and org.founded_on:
                    ipo_date = datetime.datetime.strptime(current_ipo.went_public_on, '%Y-%m-%d')
                    acq_time = (ipo_date - org.founded_on).days
                else:
                    acq_time = None
                    ipo_date = None
                cur.execute('UPDATE companies SET exit=?, exit_time=? WHERE name=?',\
                            ('IPO',ipo_date,company_link))

            elif org.acquired_by:
                acquisition = cb.acquisition(org.acquired_by[0].uuid)

                if acquisition.announced_on and org.founded_on:
                    acq_time = (acquisition.announced_on - org.founded_on).days
                    acq_date = acquisition.announced_on
                else:
                    acq_date = None
                try:
                    cur.execute('UPDATE companies SET exit=?, exit_time=? WHERE name=?',\
                            ('acquired by '+str(acquisition.acquirer[0]),acq_date,company_link))
                except:
                    cur.execute('UPDATE companies SET exit=?, exit_time=? WHERE name=?',\
                            ('acquired by ',acq_date,company_link))



                cur.execute('UPDATE companies SET exit_price=? WHERE name=?',\
                            ( acquisition.price,company_link))



            elif org.closed_on:
                cur.execute('UPDATE companies SET exit=? WHERE name = ?',\
                            ('closed',company_link))


            conn.commit()
            cur.execute('SELECT id FROM companies WHERE name=?',(company_link,))
            company_ID = cur.fetchone()[0]
            print company_link, "companies", len(company_list)




        #loop through all fundraising rounds and get info
#             for fr in org.funding_rounds:
#                 counter +=1
#                 if counter == 40:
#                     counter = 0
#                     time.sleep(60)
#                 rounds = cb.funding_round(fr.uuid)
#                 time_passed = rounds.announced_on - org.founded_on
#                 cur.execute('INSERT INTO fundraises (company, type, round, amount, time) VALUES (?, ?, ?, ?, ?)',\
#                             (company_ID, rounds.funding_type, rounds.series, rounds.money_raised_usd, time_passed.days))
            conn.commit()
conn.close()
# Out:
# started

# %%
conn = sqlite3.connect('crunchbase.db')
cur = conn.cursor()

cur.execute('SELECT name FROM companies')
count = 0
comp_names = []
for row in cur:
    comp_names.append(row[0])
    
print "started"
for name in comp_names[509:]:
    try:
        org = cb.organization(name)
    except:
        time.sleep(90)
        org = cb.organization(name)
        
    print name
    #Get company ID
    cur.execute("SELECT id FROM companies WHERE name=(?)",(name,))
    company_ID = cur.fetchone() 
    cur.execute("DELETE FROM fundraises WHERE company = (?)",company_ID)
    
    
    #loop through all fundraising rounds and get info
    for fr in org.funding_rounds:
        
        try:
            rounds = cb.funding_round(fr.uuid)
        except:
            time.sleep(90)
            rounds = cb.funding_round(fr.uuid)
            
        #get time round was raised
        try:
            announced = rounds.announced_on
        except:
            announced=None
            
        #get type
        try: 
            funding_type = rounds.funding_type
        except:
            funding_type=None
            
        #GET SERIES
        try:
            series = rounds.series
        except:
            series = None
            
        #Get Money
        try:
            amount = rounds.money_raised_usd
        except:
            amount = None
         
        #GET INVESTORS
        investors = []
        if rounds.investments:
            for inv in rounds.investments:
                investors.append(inv.investor)
                try:
                    cur.execute("INSERT INTO fundraises (investors) VALUES (?)",(str(inv.investor),))
                except:
                    continue
        
        
        #THROW IT ALL IN THERE
        cur.execute('INSERT INTO fundraises (company, type, round, amount, time) VALUES (?, ?, ?, ?, ?)',\
                    (company_ID[0], funding_type, series, amount, announced))

        conn.commit()
conn.close()
# Out:
# started
# saladax-biomedical
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-40-1c8b1fbacfd3> in <module>()
#      30         except:
#      31             time.sleep(90)
# ---> 32             rounds = cb.funding_round(fr.uuid)
#      33
#      34         #get time round was raised
#
# /Users/Ryan/anaconda/lib/python2.7/site-packages/pycrunchbase/pycrunchbase.py in funding_round(self, uuid)
#      62             FundingRound or None
#      63         """
# ---> 64         node_data = self.get_node('funding-round', uuid)
#      65         return FundingRound(node_data) if node_data else None
#      66
#
# /Users/Ryan/anaconda/lib/python2.7/site-packages/pycrunchbase/pycrunchbase.py in get_node(self, node_type, uuid, params)
#     104         """
#     105         node_url = self.BASE_URL + node_type + '/' + uuid
# --> 106         data = self._make_request(node_url, params=params)
#     107         if not data or data.get('error'):
#     108             return None
#
# /Users/Ryan/anaconda/lib/python2.7/site-packages/pycrunchbase/pycrunchbase.py in _make_request(self, url, params)
#     165         final_url = self._build_url(url, params)
#     166         response = requests.get(final_url)
# --> 167         response.raise_for_status()
#     168         return response.json().get('data')
#     169
#
# /Users/Ryan/anaconda/lib/python2.7/site-packages/requests/models.pyc in raise_for_status(self)
#     829
#     830         if http_error_msg:
# --> 831             raise HTTPError(http_error_msg, response=self)
#     832
#     833     def close(self):
#
# HTTPError: 401 Client Error: Unauthorized

# %%
# conn = sqlite3.connect('crunchbase.db')
# cur = conn.cursor()
# cur.execute("SELECT * FROM fundraises")
# count = 0
# for row in cur:
#     print row
#     count+=1
# print count
# conn.close()



import pandas as pd
import numpy as np
import seaborn as sns
import time
import sqlite3
import datetime

conn = sqlite3.connect('crunchbase.db')
cur = conn.cursor()


companies = pd.read_sql_query('SELECT * FROM companies WHERE founded_on>1995', conn, index_col='id')
# Out:
# <type 'NoneType'>
#                            name  founded_on  rounds  total_raised  \
# id
# 3                           xdx        2000       8     126397292
# 4                     heartflow        2007       5     172715918
# 5                     biocartis        2007       7     321184551
# 6          crescendo-bioscience        2002       4     146600003
# 7     htg-molecular-diagnostics        1997       5      47232377
# 8                         aviir        2005       8      26380000
# 9           daktari-diagnostics        2008       7      52119995
# 10            tethys-bioscience        2002       2      30400000
# 11                      irhythm        2006       8     104671781
# 13       integrated-diagnostics        2009       6      89050000
# 14                    metabolon        2000       6      52420551
# 15                     integenx        2006       5      88200000
# 16                  bg-medicine        2000       7      96129290
# 17                 autogenomics        1999       5      55153254
# 18        taurx-pharmaceuticals        2002       2      42000000
# 19                     cardiodx        2004       8     263990348
# 20                bionanomatrix        2003       6     102082814
# 21       predictive-biosciences        2006       3      56750000
# 22            horizon-discovery        2007       5      50251719
# 24                     diadexus        1997       4      68700000
# 27                     veracyte        2008       3      70950000
# 28                    quanterix        2007       5      43999999
# 29            metamark-genetics        2007       4      46759287
# 31                     nodality        2003       5      27039999
# 34                second-genome        2009       3      18999999
# 35          molecular-detection        2007       5       9749590
# 37                     singulex        2003       7     127336875
# 38                 pathogenetix        1997       5      24010453
# 41                 transgenomic        1997       3      10750000
# 42               astute-medical        2007       6     106134083
# ..                          ...         ...     ...           ...
# 577                      syngen        2009       5      11500000
# 578                glide-health        2008       1       1000000
# 579                     okcopay        2011       1        100000
# 580                  gordiantec        2011       1       1131092
# 582                   ameripath        1996       1             0
# 583                gamma-basics        2009       1        125000
# 584                    sense-ly        2013       2       1278000
# 585                 infermedica        2012       2        310000
# 586               cm-tecnologia        2012       1        525000
# 587                  ikonopedia        2012       2       1075000
# 589                mec-dynamics        2003       1       9549115
# 590        nova-medical-centers        2009       1             0
# 592         sleep-healthcenters        1997       1       1045984
# 594                      topera        2010       3      31518531
# 595  intelligent-fingerprinting        2007       2       4282838
# 596           nextimage-medical        2008       3      10100000
# 597            spot-on-sciences        2010       1        750000
# 598                      dbmedx        2010       3       2973267
# 599                 cardiosonic        2009       1       6100000
# 604                     doctorc        2013       1        410000
# 611                      ravgen        2000       1       1091663
# 614           spark-diagnostics        2011       1        500000
# 615   kyma-medical-technologies        2008       1      10000000
# 618                       svbio        2011       2      20500000
# 620             smart-holograms        2001       1       6790000
# 623    visionscope-technologies        2007       2      10300000
# 624                     optovue        2003       1      10500000
# 628                  medtest-dx        2011       1             0
# 629                     curefab        2009       1             0
# 631            tobii-technology        2001       4      71779200
#
#                             exit            exit_time  exit_price
# id
# 3                            IPO                 None         NaN
# 4                           None                 None         NaN
# 5                           None                 None         NaN
# 6    acquired by Myriad Genetics  2014-02-04 00:00:00   270000000
# 7                           None                 None         NaN
# 8                           None                 None         NaN
# 9                           None                 None         NaN
# 10                          None                 None         NaN
# 11                          None                 None         NaN
# 13                          None                 None         NaN
# 14                          None                 None         NaN
# 15                          None                 None         NaN
# 16                           IPO  2011-02-04 00:00:00         NaN
# 17                           IPO  2014-10-08 00:00:00         NaN
# 18                          None                 None         NaN
# 19                          None                 None         NaN
# 20                          None                 None         NaN
# 21                          None                 None         NaN
# 22                           IPO  2014-03-28 00:00:00         NaN
# 24                           IPO  1999-06-30 00:00:00         NaN
# 27                           IPO  2013-10-30 00:00:00         NaN
# 28                          None                 None         NaN
# 29                          None                 None         NaN
# 31                          None                 None         NaN
# 34                          None                 None         NaN
# 35                          None                 None         NaN
# 37                          None                 None         NaN
# 38                          None                 None         NaN
# 41                           IPO  2012-07-18 00:00:00         NaN
# 42                          None                 None         NaN
# ..                           ...                  ...         ...
# 577                         None                 None         NaN
# 578                       closed                 None         NaN
# 579                         None                 None         NaN
# 580                         None                 None         NaN
# 582                          IPO  1997-01-01 00:00:00         NaN
# 583                         None                 None         NaN
# 584                         None                 None         NaN
# 585                         None                 None         NaN
# 586                         None                 None         NaN
# 587                         None                 None         NaN
# 589                         None                 None         NaN
# 590                         None                 None         NaN
# 592                         None                 None         NaN
# 594      acquired by Abbott Labs  2014-10-29 00:00:00   250000000
# 595                         None                 None         NaN
# 596                         None                 None         NaN
# 597                         None                 None         NaN
# 598                         None                 None         NaN
# 599                         None                 None         NaN
# 604                         None                 None         NaN
# 611                         None                 None         NaN
# 614                         None                 None         NaN
# 615                         None                 None         NaN
# 618                         None                 None         NaN
# 620                         None                 None         NaN
# 623                         None                 None         NaN
# 624                         None                 None         NaN
# 628                         None                 None         NaN
# 629                         None                 None         NaN
# 631                         None                 None         NaN
#
# [392 rows x 7 columns]

# %%
IPO_companies = pd.read_sql_query('SELECT * FROM companies '  
                                  'WHERE exit LIKE "%ipo%" ', \
                                  conn, index_col='id')

Acq_companies = pd.read_sql_query('SELECT * FROM companies ' 
                                  'WHERE exit LIKE "%acquired%" ', \
                                  conn, index_col='id')

Acq_companies.dropna(subset=['exit_time'], inplace = True)
IPO_companies.dropna(subset=['exit_time'], inplace = True)

IPO_companies
# Out:
#                                  name  founded_on  rounds  total_raised  \
# id
# 16                        bg-medicine        2000       7      96129290
# 17                       autogenomics        1999       5      55153254
# 22                  horizon-discovery        2007       5      50251719
# 24                           diadexus        1997       4      68700000
# 25                            hologic        1985       1     450000000
# 27                           veracyte        2008       3      70950000
# 33               pressure-biosciences        1978       8       9428756
# 36                           sequenom        1994       3     183117265
# 40                     exact-sciences        1995       1       8200000
# 41                       transgenomic        1997       3      10750000
# 43                         nanosphere        1999       1      30200000
# 53              stemline-therapeutics        2003       4      15090000
# 66                        opko-health        2005       2     206000000
# 72                   oxford-immunotec        2002       4     106550010
# 87                          morphosys        1992       1     126000000
# 89                invitae-corporation        2012       5     195502111
# 92                response-biomedical        1992       6      21665600
# 101                  newlink-genetics        1999       3      45214105
# 105                exagen-diagnostics        2002       8      52215869
# 115           stellar-biotechnologies        1999       6      17566976
# 117                          cormedix        2006       3       6469973
# 129  american-caresource-holdings-inc        1995       5      18121600
# 148                         trovagene        1999       3      25358200
# 149        navidea-biopharmaceuticals        1983       2      32500000
# 154                          genenews        1998       6      19904010
# 163                    vermillion-inc        1993       4      84392358
# 172            prometic-life-sciences        1992       2      25100000
# 189            genetic-technologies-2        1987       2      20374046
# 195               microbix-biosystems        1988       4       2132417
# 215                   atossa-genetics        2009       2       7600000
# 263                        volitionrx        2010       2       4000000
# 268                           biomoda        2013       1       1000000
# 287                             wilex        1997       2      27070000
# 404                   cancer-genetics        1999       1       6618000
# 414           third-wave-technologies        1993       1      25000000
# 425                guava-technologies        1998       2             0
# 438               foundation-medicine        2010       4      96500000
# 454                             alere        1981       1     400000000
# 458            accelerate-diagnostics        2004       4      63016244
# 470                         visualant        1998       8       6481000
# 503                       osi-systems        1987       1       5000000
# 559                     t2-biosystems        2006       5      83500000
# 570                   cambridge-heart        1990       3       7200000
# 582                         ameripath        1996       1             0
#
#                       exit            exit_time  exit_price
# id
# 16                     IPO  2011-02-04 00:00:00         NaN
# 17                     IPO  2014-10-08 00:00:00         NaN
# 22                     IPO  2014-03-28 00:00:00         NaN
# 24                     IPO  1999-06-30 00:00:00         NaN
# 25                     IPO  1990-03-09 00:00:00         NaN
# 27                     IPO  2013-10-30 00:00:00         NaN
# 33                     IPO  2003-01-10 00:00:00         NaN
# 36                     IPO  2000-02-11 00:00:00         NaN
# 40                     IPO  2001-01-31 00:00:00         NaN
# 41                     IPO  2012-07-18 00:00:00         NaN
# 43                     IPO  2007-11-01 00:00:00         NaN
# 53                     IPO  2013-01-29 00:00:00         NaN
# 66                     IPO  1997-03-07 00:00:00         NaN
# 72                     IPO  2013-11-22 00:00:00         NaN
# 87                     IPO  2013-08-27 00:00:00         NaN
# 89                     IPO  2015-02-12 00:00:00         NaN
# 92                     IPO  2003-12-01 00:00:00         NaN
# 101                    IPO  2011-11-14 00:00:00         NaN
# 105                    IPO  2014-09-22 00:00:00         NaN
# 115                    IPO  2010-04-30 00:00:00         NaN
# 117                    IPO  2010-03-25 00:00:00         NaN
# 129                    IPO  2006-01-06 00:00:00         NaN
# 148                    IPO  2012-06-08 00:00:00         NaN
# 149                    IPO  1992-11-10 00:00:00         NaN
# 154                    IPO  2001-01-12 00:00:00         NaN
# 163                    IPO  2003-01-10 00:00:00         NaN
# 172                    IPO  2001-12-05 00:00:00         NaN
# 189                    IPO  2005-09-02 00:00:00         NaN
# 195                    IPO  1999-04-09 00:00:00         NaN
# 215                    IPO  2012-11-08 00:00:00         NaN
# 263                    IPO  2011-10-11 00:00:00         NaN
# 268                    IPO  2006-11-30 00:00:00         NaN
# 287                    IPO  2006-11-24 00:00:00         NaN
# 404                    IPO  2013-06-06 00:00:00         NaN
# 414                    IPO  2001-02-09 00:00:00         NaN
# 425  acquired by Millipore  2009-02-02 00:00:00    22600000
# 438                    IPO  2013-09-25 00:00:00         NaN
# 454                    IPO  1997-02-12 00:00:00         NaN
# 458                    IPO  2013-09-03 00:00:00         NaN
# 470                    IPO  2006-04-18 00:00:00         NaN
# 503                    IPO  1997-10-02 00:00:00         NaN
# 559                    IPO  2014-08-08 00:00:00         NaN
# 570                    IPO  1996-07-08 00:00:00         NaN
# 582                    IPO  1997-01-01 00:00:00         NaN

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter

IPO_times = [int(x[:4]) for x in IPO_companies['exit_time'].tolist()]
Acq_times = [int(x[:4]) for x in Acq_companies['exit_time'].tolist()]

# y,binEdges=np.histogram(data,bins=100)
# bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
# p.plot(bincenters,y,'-')

bins = np.linspace(2007, 2015, 9)

plt.rc('xtick', labelsize=15) 
plt.rc('ytick', labelsize=15)
plt.rc('legend',fontsize=15)
plt.rc('axes',labelsize=15)

plt.figure(num=None, figsize=(8, 6), dpi=80)
plt.hist(IPO_times, bins, color="#6495ED", alpha=.5, histtype = 'stepfilled')
plt.hist(Acq_times, bins, color="#F08080", alpha=.5, histtype = 'stepfilled')


ax = plt.gca()
ax.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))
plt.xlabel("Year")
plt.ylabel("number of exits") 
plt.legend(['IPOs','Acquisitions'], loc=2)

plt.show()

# %%
# IPO_freqs = plt.hist(IPO_times, bins, color="#6495ED", alpha=.5, histtype = 'step')[0]
# Acq_freqs = plt.hist(Acq_times, bins, color="#F08080", alpha=.5, histtype = 'step')[0]

bincenters = 0.5*(bins[1:]+bins[:-1])

# plt.rc('xtick', labelsize=15) 
# plt.rc('ytick', labelsize=15)
# plt.rc('legend',fontsize=15)
# plt.rc('axes',labelsize=15)

plt.figure(num=None, figsize=(8, 6), dpi=80)
plt.plot(bincenters, IPO_freqs, '-', color='#6495ED')
plt.plot(bincenters, Acq_freqs, '-',color='#F08080')

ax = plt.gca()
ax.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))
plt.xlabel("Year")
plt.ylabel("number of exits") 
plt.legend(['IPOs','Acquisitions'], loc=2)

plt.show()

# %%
IPO_companies = pd.read_sql_query('SELECT * FROM companies '  
                                  'WHERE exit LIKE "%ipo%" ', \
                                  conn, index_col='id')

Acq_companies = pd.read_sql_query('SELECT * FROM companies ' 
                                  'WHERE exit LIKE "%acquired%" ', \
                                  conn, index_col='id')

Acq_companies.dropna(subset=['exit_time'], inplace = True)
IPO_companies.dropna(subset=['exit_time'], inplace = True)

# %%
# conn = sqlite3.connect('crunchbase.db')
# cur = conn.cursor()

# cur.execute('SELECT name FROM companies')
# count = 0
# comp_names = []
# for row in cur:
#     comp_names.append(row[0])
    
# conn.close()

redos = ['samsung-electronics','ge-healthcare','theranos',\
 'ingenious-med','tobii-technology','siemens-healthcare','nanostring-technologies']
# Out:
# (u'121nexus',)
# (u'20-20-gene-systems-inc',)
# (u'a-g-pharmaceutical',)
# (u'abcelex-technologies',)
# (u'abcodia',)
# (u'abgenomics',)
# (u'abingdon-health',)
# (u'abionic',)
# (u'absolute-antibody',)
# (u'accel-diagnostics',)
# (u'accelerate-diagnostics',)
# (u'access-closure',)
# (u'accunostics',)
# (u'activaero',)
# (u'activelifescientific',)
# (u'activiomics',)
# (u'acuitas-medical',)
# (u'acumen-pharmaceuticals',)
# (u'adaptive-tcr',)
# (u'adarza-biosystems',)
# (u'adlyfe',)
# (u'adnavance-technologies',)
# (u'advanced-accelerator-applications',)
# (u'advanced-cell-diagnostics',)
# (u'advandx',)
# (u'affibody',)
# (u'affinimark-technologies',)
# (u'affomix-corporation',)
# (u'agendia',)
# (u'aggredyne',)
# (u'akonni-biosystems',)
# (u'alere',)
# (u'allele-biotech',)
# (u'alliedpath',)
# (u'alliqua',)
# (u'alseres-pharmaceuticals',)
# (u'alt-bioscience',)
# (u'altammune',)
# (u'altheadx',)
# (u'amadix',)
# (u'amdl',)
# (u'american-biosurgical',)
# (u'american-caresource-holdings-inc',)
# (u'american-laser-healthcare',)
# (u'american-pathology-partners',)
# (u'ameripath',)
# (u'amorfix-life-sciences',)
# (u'anagnostics',)
# (u'analiza',)
# (u'anapa-biotech',)
# (u'ancera',)
# (u'angiocrine-bioscience',)
# (u'applied-biocode',)
# (u'applied-immune-technologies',)
# (u'applied-proteomics',)
# (u'applied-stemcell',)
# (u'apta-biosciences',)
# (u'arctic-diagnostics',)
# (u'arcxis-biotechnologies',)
# (u'ari-inc',)
# (u'aria-analytics',)
# (u'ariadne-diagnostics',)
# (u'ariosa-diagnostics-inc',)
# (u'armune-bioscience',)
# (u'arrayit',)
# (u'arrogene',)
# (u'arterial-health-international',)
# (u'ascendant-dx',)
# (u'astute-medical',)
# (u'asuragen',)
# (u'atherotech-diagnostics-lab',)
# (u'ativa-medical',)
# (u'atlas-genetics',)
# (u'atossa-genetics',)
# (u'augury-systems',)
# (u'aureon-laboratories',)
# (u'aushon-biosystems',)
# (u'autogenomics',)
# (u'avantra-biosciences',)
# (u'aviir',)
# (u'axiomx',)
# (u'axxess-pharma',)
# (u'b3-bio',)
# (u'bg-medicine',)
# (u'bigml',)
# (u'bikanta',)
# (u'bioapter',)
# (u'biocartis',)
# (u'biocept',)
# (u'biocision',)
# (u'biodesix',)
# (u'biofire-diagnostics',)
# (u'biofortuna',)
# (u'biolight-israeli-life-sciences-investments-ltd',)
# (u'biomarcare-technologies',)
# (u'biomarker-strategies',)
# (u'biomedix-vascular-solution',)
# (u'biomeme',)
# (u'biomoda',)
# (u'biomode-biomolecular-determination',)
# (u'bionanomatrix',)
# (u'bionanovations',)
# (u'bioscale',)
# (u'biosceptre',)
# (u'bioscience',)
# (u'biosensia',)
# (u'biotime',)
# (u'bioventus',)
# (u'bioxydyn',)
# (u'blend-therapeutics',)
# (u'blueprint-genetics',)
# (u'boreal-genomics',)
# (u'brain-tunnelgenix-technologies',)
# (u'brightbox-technologies',)
# (u'c3-jian',)
# (u'cambridge-epigenetix',)
# (u'cambridge-heart',)
# (u'canbridge-life-sciences',)
# (u'cancer-genetics',)
# (u'cancer-prevention-pharmaceuticals',)
# (u'cancerguide-diagnostics',)
# (u'cardiodx',)
# (u'cardiogenics',)
# (u'cardiosonic',)
# (u'carista-app',)
# (u'carmenta-bioscience',)
# (u'cblpath',)
# (u'cd-diagnostics',)
# (u'celerus-diagnostics',)
# (u'cell-point',)
# (u'cellphire',)
# (u'cellply',)
# (u'cellscape',)
# (u'celmatix',)
# (u'centre-for-sight',)
# (u'cerescan',)
# (u'cernostics',)
# (u'chartwise-medical-systems',)
# (u'chemclin',)
# (u'chesapeake-perl',)
# (u'chorafarma',)
# (u'cis-biotech',)
# (u'claremont-biosolutions',)
# (u'clarient',)
# (u'claritas-genomics',)
# (u'claro-scientific',)
# (u'claros-diagnostics',)
# (u'clear-image-technology',)
# (u'clearbridge-biomedics',)
# (u'cleveland-heartlab',)
# (u'cm-tecnologia',)
# (u'cognuse',)
# (u'collabrx-inc',)
# (u'combimatrix',)
# (u'compressus',)
# (u'conelum',)
# (u'core-diagnostics',)
# (u'corgenix',)
# (u'corimmun',)
# (u'cormedix',)
# (u'crescendo-bioscience',)
# (u'critical-biologics-corporation',)
# (u'crowdmed',)
# (u'crystalplex',)
# (u'ctd-holdings',)
# (u'cubresa',)
# (u'curefab',)
# (u'curetis',)
# (u'cvergenx',)
# (u'cylex',)
# (u'cymogen-dx',)
# (u'cyntellect',)
# (u'cynvenio-biosystems',)
# (u'cytonics',)
# (u'daktari-diagnostics',)
# (u'daylight-solutions',)
# (u'dbmedx',)
# (u'dedalus-group',)
# (u'definiens',)
# (u'dezide',)
# (u'diabetomics',)
# (u'diacarta',)
# (u'diadexus',)
# (u'diagnostic-biochips',)
# (u'diagnostic-healthcare',)
# (u'diagnostic-hybrids',)
# (u'diagnostic-imaging-international',)
# (u'diagnovus',)
# (u'diassess',)
# (u'diatech-oncology',)
# (u'diatherix-laboratories',)
# (u'digeprint',)
# (u'digisight-technologies',)
# (u'diogenix',)
# (u'disease-diagnostic-group',)
# (u'doctorc',)
# (u'dormir',)
# (u'dune-medical-devices',)
# (u'dxna',)
# (u'dxupclose',)
# (u'ebioscience',)
# (u'edp-biotech',)
# (u'elucid-bioimaging',)
# (u'emerald-logic',)
# (u'emerge-diagnostics',)
# (u'empire-genomics',)
# (u'endochoice',)
# (u'enterome',)
# (u'envirogene',)
# (u'epic-sciences',)
# (u'epigenomics-ag',)
# (u'epinex-diagnostics',)
# (u'epiphany',)
# (u'epivios',)
# (u'eragen-biosciences',)
# (u'erydel',)
# (u'everist-genomics',)
# (u'evident-health',)
# (u'exact-sciences',)
# (u'exagen-diagnostics',)
# (u'exosome-diagnostics',)
# (u'externautics',)
# (u'eyenetra',)
# (u'fabpulous',)
# (u'firalis',)
# (u'first-warning-systems',)
# (u'flexible-medical-systems',)
# (u'flowmetric',)
# (u'fluoropharma',)
# (u'foundation-medicine',)
# (u'foundation-radiology-group',)
# (u'freedom-meditech',)
# (u'gamma-basics',)
# (u'gamma-medica-ideas',)
# (u'ge-healthcare',)
# (u'gema',)
# (u'genapsys',)
# (u'gene-solutions',)
# (u'geneassess',)
# (u'genecentric-diagnostics',)
# (u'genenews',)
# (u'genetic-technologies-2',)
# (u'genevolve-vision-diagnostics',)
# (u'geneweave-biosciences',)
# (u'genisphere-inc',)
# (u'genomed',)
# (u'genomic-expression',)
# (u'genprime',)
# (u'genqual-corporation',)
# (u'glide-health',)
# (u'glycominds',)
# (u'goddard-labs',)
# (u'gold-standard-diagnostics',)
# (u'gopath-global',)
# (u'gordiantec',)
# (u'gradalis',)
# (u'grand-round-table',)
# (u'grantadler',)
# (u'great-basin-corporation',)
# (u'guangzhou-huafeng-biotech-co-ltd',)
# (u'guardant-health',)
# (u'guava-technologies',)
# (u'headsense-medical',)
# (u'healcerion',)
# (u'health-discovery',)
# (u'health-wildcatters',)
# (u'healthhiway',)
# (u'heartflow',)
# (u'helicos-biosciences',)
# (u'helixis',)
# (u'hemosonics',)
# (u'hibergene-diagnostics',)
# (u'hologic',)
# (u'horizon-discovery',)
# (u'htg-molecular-diagnostics',)
# (u'hubble-telemedical',)
# (u'human-longevity',)
# (u'hx-diagnostics',)
# (u'icb-international',)
# (u'ikonisys',)
# (u'ikonopedia',)
# (u'im3d',)
# (u'imaginab',)
# (u'immunetics',)
# (u'immunexpress',)
# (u'immunotegg',)
# (u'immusant',)
# (u'impact-medical-strategies',)
# (u'imspex-diagnostics',)
# (u'inbiomotion',)
# (u'incelldx',)
# (u'indigo-biosystems',)
# (u'infermedica',)
# (u'infinity-telemedicine-group',)
# (u'informedika',)
# (u'ingenious-med',)
# (u'innogenetics',)
# (u'innovolt',)
# (u'inovise-medical',)
# (u'insight-genetics',)
# (u'insilixa',)
# (u'instant-labs-medical-diagnostics-corp',)
# (u'integenx',)
# (u'integrated-diagnostics',)
# (u'intelligenescan',)
# (u'intelligent-fingerprinting',)
# (u'intelligent-ultrasound',)
# (u'intelligentmdx',)
# (u'intellirod-spine',)
# (u'international-telematics',)
# (u'intraop',)
# (u'intuitive-biosciences',)
# (u'inverness-medical-innovations',)
# (u'invisible-sentinel',)
# (u'invitae-corporation',)
# (u'iota-computing',)
# (u'irhythm',)
# (u'isoplexis',)
# (u'iv-diagnostics',)
# (u'iverson-genetic-diagnostics',)
# (u'jan-medical',)
# (u'jeeri-neotech-international',)
# (u'juneau-biosciences',)
# (u'kaiser-permanente',)
# (u'kanichi-research-services',)
# (u'kjaya-medical',)
# (u'kreatech-diagnostics',)
# (u'kyma-medical-technologies',)
# (u'kypha',)
# (u'lab21',)
# (u'labnow',)
# (u'laboratory-partners',)
# (u'lasergen',)
# (u'laureate-pharma',)
# (u'lifeimage',)
# (u'lightspeed-genomics',)
# (u'lineagen',)
# (u'linkage-biosciences',)
# (u'logicnets',)
# (u'lookmedbook',)
# (u'lophius-biosciences',)
# (u'lumacyte',)
# (u'lumora',)
# (u'lyzer-diagnostics',)
# (u'maculogix',)
# (u'madison-vaccines',)
# (u'magenta-computacion',)
# (u'manipal-acunova',)
# (u'maven-biotechnologies',)
# (u'mayo-clinic-rochester',)
# (u'mbio-diagnostics',)
# (u'mdsave',)
# (u'mdxhealth',)
# (u'mec-dynamics',)
# (u'medibeacon',)
# (u'medical-metrx-solutions',)
# (u'medical-predictive-science-corporation',)
# (u'medical-technologies-international',)
# (u'medsolutions',)
# (u'medtest-dx',)
# (u'medymatch',)
# (u'memed',)
# (u'memobead-technologies',)
# (u'mesi',)
# (u'mesolight-llc',)
# (u'metabolomic-diagnostics',)
# (u'metabolon',)
# (u'metamark-genetics',)
# (u'metastat',)
# (u'mformation-technologies',)
# (u'microbix-biosystems',)
# (u'microphage',)
# (u'microtest-diagnostics',)
# (u'minivax',)
# (u'mira-dx',)
# (u'mitoprod',)
# (u'mobileoct',)
# (u'mode-diagnostics',)
# (u'molecular-detection',)
# (u'molecular-partners',)
# (u'molecularmd',)
# (u'morphosys',)
# (u'multiplicom',)
# (u'mylabyogi-com',)
# (u'myoonet',)
# (u'n-of-one-therapeutics',)
# (u'nanobiotix',)
# (u'nanocellect',)
# (u'nanodetection-technology',)
# (u'nanosphere',)
# (u'nanostring-technologies',)
# (u'nanthealth',)
# (u'natera',)
# (u'navidea-biopharmaceuticals',)
# (u'neoantigenics',)
# (u'neodiagnostix',)
# (u'neogenix-oncology',)
# (u'nerveda',)
# (u'netscientific',)
# (u'neumodx-molecular',)
# (u'neurogenetic-pharmaceuticals',)
# (u'neuroquest',)
# (u'neurotrack-technologies',)
# (u'neurotrope-bioscience',)
# (u'new-planet-technologies',)
# (u'newlink-genetics',)
# (u'newmentor-com',)
# (u'nexstim',)
# (u'nextcare',)
# (u'nextcode-health',)
# (u'nextimage-medical',)
# (u'nexus-dx',)
# (u'niiki-pharma',)
# (u'ninepoint-medical',)
# (u'nirmidas-biotech',)
# (u'nodality',)
# (u'nova-medical-centers',)
# (u'novasom',)
# (u'novophage',)
# (u'nuclea-biotechnologies',)
# (u'nx-pharmagen',)
# (u'okcopay',)
# (u'on-q-ity',)
# (u'oncgnostics',)
# (u'oncohealth',)
# (u'oncovista-innovative-therapies',)
# (u'one-codex',)
# (u'ontrack-imaging',)
# (u'opko-health',)
# (u'optherion',)
# (u'opticul-diagnostics',)
# (u'optovue',)
# (u'ortho-kinematics',)
# (u'orthoscan',)
# (u'osi-systems',)
# (u'ovagene-oncology',)
# (u'oxford-biotherapeutics',)
# (u'oxford-immunotec',)
# (u'oxford-nanopore-technologies',)
# (u'oxonica',)
# (u'packettrap',)
# (u'pager',)
# (u'palindromx',)
# (u'parabase-genomics',)
# (u'parasol-therapeutics',)
# (u'parkinsor',)
# (u'path-logic',)
# (u'pathgroup',)
# (u'pathogenetix',)
# (u'pathology-holdings',)
# (u'pathway-pharmaceuticals',)
# (u'pathwork-diagnostics',)
# (u'pediatric-bioscience',)
# (u'pelikan-technologies',)
# (u'pepex-biomedical',)
# (u'pharmagen',)
# (u'phi-optics',)
# (u'phoenix-s-t',)
# (u'phthisis-diagnostics',)
# (u'phylos-bioscience',)
# (u'pipeline-biomedical-holdings',)
# (u'pivotal-systems',)
# (u'plc-diagnostics',)
# (u'pocared-diagnostics-ltd',)
# (u'population-diagnostics',)
# (u'precipio-diagnostics',)
# (u'precision-biologics',)
# (u'precision-therapeutics',)
# (u'predictive-biosciences',)
# (u'premier-diagnostics',)
# (u'pressure-biosciences',)
# (u'procept-biorobotics',)
# (u'prognomix',)
# (u'prometheus-laboratories',)
# (u'prometic-life-sciences',)
# (u'pronota',)
# (u'prostagene',)
# (u'protagen',)
# (u'protein-forest',)
# (u'proteocyte-diagnostics',)
# (u'proteotech',)
# (u'provista-diagnostics',)
# (u'quandx',)
# (u'quanterix',)
# (u'quantrx-biomedical',)
# (u'quantumdx-group',)
# (u'quotient-biodiagnostics',)
# (u'radient-pharmaceuticals',)
# (u'radisens-diagnostics',)
# (u'radisphere-national-radiology-group',)
# (u'rapid-diagnostek',)
# (u'rapid-pathogen-screening',)
# (u'rarecyte',)
# (u'ravgen',)
# (u'reametrix',)
# (u'reinnervate',)
# (u'renovar',)
# (u'resonant-sensors-inc',)
# (u'response-biomedical',)
# (u'response-genetics-inc',)
# (u'rheonix',)
# (u'rhinocyte',)
# (u'ridge-diagnostics',)
# (u'rijuven',)
# (u'rosetta-genomics',)
# (u'rubysophic',)
# (u'rxcost-containment',)
# (u'sabirmedical',)
# (u'sage-science',)
# (u'saladax-biomedical',)
# (u'samsung-electronics',)
# (u'sarnova',)
# (u'satoris',)
# (u'scanadu',)
# (u'sci-solution',)
# (u'scil-proteins',)
# (u'second-genome',)
# (u'sedia-biosciences',)
# (u'selah-genomics',)
# (u'selventa',)
# (u'seno-medical-instruments-inc',)
# (u'sense-ly',)
# (u'sensigen',)
# (u'sequenom',)
# (u'sequenta',)
# (u'sera-prognostics',)
# (u'seracare-life-sciences',)
# (u'seventh-sense-biosystems',)
# (u'shrink-nanotechnologies',)
# (u'siemens-healthcare',)
# (u'singulex',)
# (u'sirigen',)
# (u'sirs-lab',)
# (u'siteone-therapeutics',)
# (u'sividon-diagnostics',)
# (u'skuldtech',)
# (u'sleep-healthcenters',)
# (u'sleep-solutions',)
# (u'slipchip',)
# (u'smapper-technologies-gmbh',)
# (u'smart-holograms',)
# (u'solulink',)
# (u'solus-scientific-solutions',)
# (u'solvebio',)
# (u'somalogic',)
# (u'sonivate-medical',)
# (u'soricimed',)
# (u'source-mdx',)
# (u'spark-diagnostics',)
# (u'spectral-diagnostics',)
# (u'spinomix',)
# (u'spinx-technologies',)
# (u'spot-on-sciences',)
# (u'spraycool',)
# (u'stage-i-diagnostics',)
# (u'stellar-biotechnologies',)
# (u'stem-centrx',)
# (u'stemina-biomarker-discovery',)
# (u'stemline-therapeutics',)
# (u'strand-diagnostics',)
# (u'sun-diagnostics',)
# (u'suregene',)
# (u'svbio',)
# (u'swift-biosciences',)
# (u'sword-diagnostics',)
# (u'symetrica',)
# (u'syngen',)
# (u't2-biosystems',)
# (u'taurx-pharmaceuticals',)
# (u'tb-biosciences',)
# (u'techmed-healthcare',)
# (u'telepo',)
# (u'tethys-bioscience',)
# (u'the-charity-engine',)
# (u'theranos',)
# (u'theranostics-health',)
# (u'theratest-laboratories',)
# (u'thermaltherapeuticsystems',)
# (u'third-wave-technologies',)
# (u'thrombodx-bv',)
# (u'thrombovision',)
# (u'tm-bioscience',)
# (u'tobii-technology',)
# (u'topera',)
# (u'transgenomic',)
# (u'transplant-genomics-inc',)
# (u'treventis',)
# (u'trice-medical',)
# (u'trice-orthopedics',)
# (u'trovagene',)
# (u'twin-star-ecs',)
# (u'tyrosine-pharmaceuticals',)
# (u'universal-biosensors',)
# (u'universal-devices',)
# (u'usds',)
# (u'utility-associates',)
# (u'valeo-medical',)
# (u'valirx',)
# (u'vandalia-research',)
# (u'veracyte',)
# (u'vermillion-inc',)
# (u'vertical-health-solutions',)
# (u'vicor-technologies',)
# (u'victory-healthcare',)
# (u'viroclinics-biosciences',)
# (u'visionscope-technologies',)
# (u'visterra',)
# (u'visualant',)
# (u'vivacta',)
# (u'volitionrx',)
# (u'voxel-pl',)
# (u'vssb-medical-nanotechnology',)
# (u'vy-corporation',)
# (u'welcare',)
# (u'wilex',)
# (u'xagenic',)
# (u'xcell-biosciences',)
# (u'xdx',)
# (u'xlv-diagnostics',)
# (u'zealcore-embedded-solutions',)
# (u'zilico',)
# (u'zonare-medical-systems',)
# 622
# [u'121nexus', u'20-20-gene-systems-inc', u'a-g-pharmaceutical', u'abcelex-technologies', u'abcodia', u'abgenomics', u'abingdon-health', u'abionic', u'absolute-antibody', u'accel-diagnostics', u'accelerate-diagnostics', u'access-closure', u'accunostics', u'activaero', u'activelifescientific', u'activiomics', u'acuitas-medical', u'acumen-pharmaceuticals', u'adaptive-tcr', u'adarza-biosystems', u'adlyfe', u'adnavance-technologies', u'advanced-accelerator-applications', u'advanced-cell-diagnostics', u'advandx', u'affibody', u'affinimark-technologies', u'affomix-corporation', u'agendia', u'aggredyne', u'akonni-biosystems', u'alere', u'allele-biotech', u'alliedpath', u'alliqua', u'alseres-pharmaceuticals', u'alt-bioscience', u'altammune', u'altheadx', u'amadix', u'amdl', u'american-biosurgical', u'american-caresource-holdings-inc', u'american-laser-healthcare', u'american-pathology-partners', u'ameripath', u'amorfix-life-sciences', u'anagnostics', u'analiza', u'anapa-biotech', u'ancera', u'angiocrine-bioscience', u'applied-biocode', u'applied-immune-technologies', u'applied-proteomics', u'applied-stemcell', u'apta-biosciences', u'arctic-diagnostics', u'arcxis-biotechnologies', u'ari-inc', u'aria-analytics', u'ariadne-diagnostics', u'ariosa-diagnostics-inc', u'armune-bioscience', u'arrayit', u'arrogene', u'arterial-health-international', u'ascendant-dx', u'astute-medical', u'asuragen', u'atherotech-diagnostics-lab', u'ativa-medical', u'atlas-genetics', u'atossa-genetics', u'augury-systems', u'aureon-laboratories', u'aushon-biosystems', u'autogenomics', u'avantra-biosciences', u'aviir', u'axiomx', u'axxess-pharma', u'b3-bio', u'bg-medicine', u'bigml', u'bikanta', u'bioapter', u'biocartis', u'biocept', u'biocision', u'biodesix', u'biofire-diagnostics', u'biofortuna', u'biolight-israeli-life-sciences-investments-ltd', u'biomarcare-technologies', u'biomarker-strategies', u'biomedix-vascular-solution', u'biomeme', u'biomoda', u'biomode-biomolecular-determination', u'bionanomatrix', u'bionanovations', u'bioscale', u'biosceptre', u'bioscience', u'biosensia', u'biotime', u'bioventus', u'bioxydyn', u'blend-therapeutics', u'blueprint-genetics', u'boreal-genomics', u'brain-tunnelgenix-technologies', u'brightbox-technologies', u'c3-jian', u'cambridge-epigenetix', u'cambridge-heart', u'canbridge-life-sciences', u'cancer-genetics', u'cancer-prevention-pharmaceuticals', u'cancerguide-diagnostics', u'cardiodx', u'cardiogenics', u'cardiosonic', u'carista-app', u'carmenta-bioscience', u'cblpath', u'cd-diagnostics', u'celerus-diagnostics', u'cell-point', u'cellphire', u'cellply', u'cellscape', u'celmatix', u'centre-for-sight', u'cerescan', u'cernostics', u'chartwise-medical-systems', u'chemclin', u'chesapeake-perl', u'chorafarma', u'cis-biotech', u'claremont-biosolutions', u'clarient', u'claritas-genomics', u'claro-scientific', u'claros-diagnostics', u'clear-image-technology', u'clearbridge-biomedics', u'cleveland-heartlab', u'cm-tecnologia', u'cognuse', u'collabrx-inc', u'combimatrix', u'compressus', u'conelum', u'core-diagnostics', u'corgenix', u'corimmun', u'cormedix', u'crescendo-bioscience', u'critical-biologics-corporation', u'crowdmed', u'crystalplex', u'ctd-holdings', u'cubresa', u'curefab', u'curetis', u'cvergenx', u'cylex', u'cymogen-dx', u'cyntellect', u'cynvenio-biosystems', u'cytonics', u'daktari-diagnostics', u'daylight-solutions', u'dbmedx', u'dedalus-group', u'definiens', u'dezide', u'diabetomics', u'diacarta', u'diadexus', u'diagnostic-biochips', u'diagnostic-healthcare', u'diagnostic-hybrids', u'diagnostic-imaging-international', u'diagnovus', u'diassess', u'diatech-oncology', u'diatherix-laboratories', u'digeprint', u'digisight-technologies', u'diogenix', u'disease-diagnostic-group', u'doctorc', u'dormir', u'dune-medical-devices', u'dxna', u'dxupclose', u'ebioscience', u'edp-biotech', u'elucid-bioimaging', u'emerald-logic', u'emerge-diagnostics', u'empire-genomics', u'endochoice', u'enterome', u'envirogene', u'epic-sciences', u'epige ...

# %%
# cur.execute("UPDATE companies SET exit_time = NULL WHERE exit_time=?",(None,))
cur.execute("SELECT * FROM companies WHERE exit_time=?",('None',))
# conn.commit()
for row in cur:
    print row

#rounds	total_raised	exit	exit_time	exit_price

# %%
# %matplotlib inline

# %%
import datetime
s = cb.ipo(org.ipo[0].uuid).went_public_on

datetime.datetime.strptime(s, '%Y-%m-%d')
# Out:
# datetime.datetime(2003, 5, 23, 0, 0)

# %%
time.strftime("%H", time.localtime())
# Out:
# '23'
