# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (9, 9)
plt.rcParams['font.size'] = 14
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.titlesize'] = 1.5*plt.rcParams['font.size']
plt.rcParams['legend.fontsize'] = plt.rcParams['font.size']
plt.rcParams['xtick.labelsize'] = plt.rcParams['font.size']
plt.rcParams['ytick.labelsize'] = plt.rcParams['font.size']
plt.rcParams['lines.markersize'] =8
# plt.rcParams['savefig.dpi'] = 2*plt.rcParams['savefig.dpi']
# plt.rcParams['xtick.major.size'] = 3
# plt.rcParams['xtick.minor.size'] = 3
# plt.rcParams['xtick.major.width'] = 1
# plt.rcParams['xtick.minor.width'] = 1
# plt.rcParams['ytick.major.size'] = 3
# plt.rcParams['ytick.minor.size'] = 3
# plt.rcParams['ytick.major.width'] = 1
# plt.rcParams['ytick.minor.width'] = 1
# plt.rcParams['legend.frameon'] = False
# plt.rcParams['legend.loc'] = 'center left'
# plt.rcParams['axes.linewidth'] = 1

# plt.gca().spines['right'].set_color('none')
# plt.gca().spines['top'].set_color('none')
# plt.gca().xaxis.set_ticks_position('bottom')
# plt.gca().yaxis.set_ticks_position('left')

# %matplotlib inline

# %%
site_data = pd.DataFrame.from_csv('/users/ryan/downloads/USCS_1999_2012_ASCII/BYSITE.TXT', sep='|', index_col=None)
mortality = site_data[site_data['EVENT_TYPE']=='Mortality']
mortality = mortality[mortality['CRUDE_RATE']!='~']
mortality = mortality[mortality['CRUDE_RATE']!='.']
mortality = mortality[mortality['SEX']=='Male and Female']
mortality[['AGE_ADJUSTED_RATE','CRUDE_RATE']] = mortality[['AGE_ADJUSTED_RATE','CRUDE_RATE']].astype(float)


incidence = site_data[site_data['EVENT_TYPE']=='Incidence']
incidence = incidence[incidence['CRUDE_RATE']!='~']
incidence = incidence[incidence['SEX']=='Male and Female']
incidence[['AGE_ADJUSTED_RATE','CRUDE_RATE']] = incidence[['AGE_ADJUSTED_RATE','CRUDE_RATE']].astype(float)

print incidence.shape
incidence[1:10]
mortality[1:10]
# Out:
# (6860, 13)
#       YEAR       RACE              SEX               SITE EVENT_TYPE  \
# 4248  2000  All Races  Male and Female  Acute Lymphocytic  Mortality
# 4250  2001  All Races  Male and Female  Acute Lymphocytic  Mortality
# 4252  2002  All Races  Male and Female  Acute Lymphocytic  Mortality
# 4254  2003  All Races  Male and Female  Acute Lymphocytic  Mortality
# 4256  2004  All Races  Male and Female  Acute Lymphocytic  Mortality
# 4258  2005  All Races  Male and Female  Acute Lymphocytic  Mortality
# 4260  2006  All Races  Male and Female  Acute Lymphocytic  Mortality
# 4262  2007  All Races  Male and Female  Acute Lymphocytic  Mortality
# 4264  2008  All Races  Male and Female  Acute Lymphocytic  Mortality
#
#      AGE_ADJUSTED_CI_LOWER AGE_ADJUSTED_CI_UPPER  AGE_ADJUSTED_RATE COUNT  \
# 4248                   0.5                   0.5                0.5  1395
# 4250                   0.5                   0.5                0.5  1433
# 4252                   0.5                   0.5                0.5  1432
# 4254                   0.5                   0.5                0.5  1429
# 4256                   0.4                   0.5                0.5  1371
# 4258                   0.5                   0.5                0.5  1460
# 4260                   0.4                   0.5                0.5  1393
# 4262                   0.4                   0.5                0.5  1418
# 4264                   0.4                   0.5                0.5  1424
#
#       POPULATION CRUDE_CI_LOWER CRUDE_CI_UPPER  CRUDE_RATE
# 4248   282162411            0.5            0.5         0.5
# 4250   284968955            0.5            0.5         0.5
# 4252   287625193            0.5            0.5         0.5
# 4254   290107933            0.5            0.5         0.5
# 4256   292805298            0.4            0.5         0.5
# 4258   295516599            0.5            0.5         0.5
# 4260   298379912            0.4            0.5         0.5
# 4262   301231207            0.4            0.5         0.5
# 4264   304093966            0.4            0.5         0.5

# %%
organ_incidence = incidence.groupby('SITE')['CRUDE_RATE'].mean()

organ_incidence.sort()
organ_incidence
# Out:
# SITE
# Pleura                                               0.000000
# Other Male Genital Organs                            0.168254
# Trachea, Mediastinum and Other Respiratory Organs    0.177778
# Other Urinary Organs                                 0.226027
# Other Oral Cavity and Pharynx                        0.267187
# Retroperitoneum                                      0.327632
# Other Digestive Organs                               0.343421
# Cranial Nerves and Other Nervous System              0.383117
# Ureter                                               0.386842
# Oropharynx                                           0.402857
# Peritoneum, Omentum and Mesentery                    0.415789
# Lip                                                  0.468750
# Floor of Mouth                                       0.488462
# Kaposi Sarcoma                                       0.497368
# Eye and Orbit                                        0.543590
# ...
# Corpus                                18.621111
# Corpus and Uterus, NOS                19.374444
# Urinary System                        24.054444
# Colon excluding Rectum                25.245556
# Colon and Rectum                      35.393333
# Female Genital System                 40.601111
# Lung and Bronchus                     44.715556
# Respiratory System                    48.273333
# Male and Female Breast                49.718889
# Digestive System                      67.571111
# Female Breast                         96.896667
# Prostate                              98.870000
# Male Genital System                  103.454444
# All Sites (comparable to ICD-O-2)    334.437778
# All Cancer Sites Combined            338.701111
# Name: CRUDE_RATE, Length: 81, dtype: float64

# %%
incidence_2012 = incidence[incidence['YEAR'] =='2012']
mortality_2012 = mortality[mortality['YEAR'] =='2012']

organ_incidence_2012 = incidence_2012.groupby('SITE')['CRUDE_RATE'].mean()
organ_mortality_2012 = mortality_2012.groupby('SITE')['CRUDE_RATE'].mean()

# organ_incidence_2012.sort()
# organ_mortality_2012.sort()

# %%
print organ_incidence_2012.shape
print organ_mortality_2012.shape
incidence_mort = pd.concat([organ_incidence_2012, organ_mortality_2012], axis=1)
incidence_mort.columns = ['Incidence per 100,000','Mortality per 100,000']
print incidence_mort.shape
incidence_mort
# Out:
# (81,)
# (76,)
# (81, 2)
#                                                    Incidence per 100,000  \
# Acute Lymphocytic                                               1.516667
# Acute Myeloid                                                   3.233333
# All Cancer Sites Combined                                     342.200000
# All Sites (comparable to ICD-O-2)                             337.316667
# Anus, Anal Canal and Anorectum                                  1.333333
# Bones and Joints                                                0.733333
# Brain                                                           4.383333
# Brain and Other Nervous System                                  4.716667
# Cervix                                                          7.166667
# Chronic Lymphocytic                                             2.633333
# Chronic Myeloid                                                 1.283333
# Colon and Rectum                                               32.133333
# Colon excluding Rectum                                         22.483333
# Corpus                                                         21.800000
# Corpus and Uterus, NOS                                         22.633333
# Cranial Nerves and Other Nervous System                         0.340000
# Digestive System                                               67.650000
# Endocrine System                                               12.433333
# Esophagus                                                       3.216667
# Eye and Orbit                                                   0.540000
# Female Breast                                                 102.550000
# Female Genital System                                          43.083333
# Floor of Mouth                                                  0.420000
# Gallbladder                                                     1.150000
# Gum and Other Mouth                                             1.200000
# Ureter                                                          0.100000
# Urinary Bladder                                                 2.700000
# Urinary System                                                  5.833333
# Uterus, NOS                                                     2.500000
# Vagina                                                          0.225000
# Vulva                                                           0.475000
#
# [81 rows x 2 columns]

# %%
drug_dev = {
'Urinary Bladder' : 18,
'Brain and Other Nervous System' : 47,
'Female Breast' : 73,
'Colon and Rectum' : 46,
'Oral Cavity and Pharynx' : 19,
'Kidney and Renal Pelvis' : 24,
'Leukemias' : 87,
'Liver and Intrahepatic Bile Duct' : 37,
'Lung and Bronchus' : 98,
'Lymphomas' : 78,
'Myeloma' : 33,
'Ovary' : 48,
'Pancreas' : 39,
'Prostate' : 45,
'Kaposi Sarcoma' : 11,
'Skin excluding Basal and Squamous' : 56,
'Stomach' : 24, }

drugs = pd.Series(drug_dev)

inc_mort_drugs = pd.merge(incidence_mort, pd.DataFrame(drugs), right_index=True, left_index=True)
inc_mort_drugs.rename(columns = {0:'Drugs in Development'}, inplace = True)

# %%
print inc_mort_drugs.shape
inc_mort_drugs.columns
# Out:
# (17, 3)
# Index([u'Incidence per 100,000', u'Mortality per 100,000', u'Drugs in Development'], dtype='object')

# %%
plt.figure(figsize=(8,6))
sns.regplot('Incidence per 100,000', 'Mortality per 100,000', data=inc_mort_drugs, fit_reg=False, scatter_kws={'s':60})

# for label, x, y in zip(inc_mort_drugs.index.tolist(), inc_mort_drugs['Incidence per 100,000'], inc_mort_drugs['Mortality per 100,000']):
#     plt.annotate(
#         label, 
#         xy = (x, y), xytext = ((np.random.rand(1)-.5)*100, (np.random.rand(1)-.5)*300),
#         textcoords = 'offset points', ha = 'right', va = 'bottom',
# #         bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
#         arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

# %%
plt.figure(figsize=(8,6))
sns.regplot('Incidence per 100,000', 'Drugs in Development', data=inc_mort_drugs, fit_reg=False, scatter_kws={'s':60})
labels = []
for i in inc_mort_drugs.index.tolist():
    label.append(i.split()[[0]])

for label, x, y in zip(labels, \
                       inc_mort_drugs['Incidence per 100,000'], \
                       inc_mort_drugs['Drugs in Development']):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (60, 15),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
#         bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-184-3a89036c9061> in <module>()
#       3 labels = []
#       4 for i in inc_mort_drugs.index.tolist():
# ----> 5     label.append(i.split()[[0]])
#       6
#       7 for label, x, y in zip(labels,                        inc_mort_drugs['Incidence per 100,000'],                        inc_mort_drugs['Drugs in Development']):
#
# AttributeError: 'str' object has no attribute 'append'

# %%
plt.figure(figsize=(8,6))
sns.regplot('Incidence per 100,000', 'Drugs in Development', data=inc_mort_drugs, fit_reg=False, scatter_kws={'s':60})
plt.axis((0, 33, 0, 60))

for label, x, y in zip(inc_mort_drugs.index.tolist(), \
                       inc_mort_drugs['Incidence per 100,000'], \
                       inc_mort_drugs['Drugs in Development']):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (80, -20),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
#         bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))
